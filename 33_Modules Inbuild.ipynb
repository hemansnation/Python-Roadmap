# %% [markdown]
# # Modules & Packages
# Different types of modules
#
# Inbuilt modules
#
# OS
#
# Sys
#
# Statistics
#
# Math
#
# String
#
# Random
#
# Create your own module
#
# Building Packages
#
# Build your own python module and deploy it on pip

# %% [markdown]
# # OS

# %%
import os

# %%
# help(os)

# %%
# make directory/folder
os.mkdir('indoreimages')

# %%
# get current working directory
os.getcwd()
# Out:
# '/home/heman/Documents/Python 2022/Python-Roadmap-2022'

# %%
# remove directory
os.rmdir('indoreimages')

# %% [markdown]
# # sys

# %%
import sys

# %%
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/heman/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
sys.maxsize
# Out:
# 9223372036854775807

# %%
sys.path
# Out:
# ['/home/heman/Documents/Python 2022/Python-Roadmap-2022',
#  '/home/heman/anaconda3/lib/python37.zip',
#  '/home/heman/anaconda3/lib/python3.7',
#  '/home/heman/anaconda3/lib/python3.7/lib-dynload',
#  '',
#  '/home/heman/.local/lib/python3.7/site-packages',
#  '/home/heman/anaconda3/lib/python3.7/site-packages',
#  '/home/heman/anaconda3/lib/python3.7/site-packages/IPython/extensions',
#  '/home/heman/.ipython']

# %%
sys.version
# Out:
# '3.7.6 (default, Jan  8 2020, 19:59:22) \n[GCC 7.3.0]'

# %% [markdown]
# # statistics

# %%
# import statistics

# statistics.mean()

# %%
from statistics import *

ages = [20, 10, 4, 25, 26, 88, 18, 21, 25]

print(mean(ages))
# Out:
# 26.333333333333332

# %%
print(median(ages))
# Out:
# 21

# %%
print(mode(ages))
# Out:
# 25

# %%
print(stdev(ages))
# Out:
# 24.264171117101856

# %% [markdown]
# # math

# %%
import math

print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.sqrt(2))
# Out:
# 1.4142135623730951

# %%
print(math.pow(2,3))
# Out:
# 8.0

# %%
print(math.floor(9.5))
# Out:
# 9

# %%
print(math.ceil(9.5))
# Out:
# 10

# %%
print(math.ceil(9.1))
# Out:
# 10

# %%
print(math.log10(100))
# Out:
# 2.0

# %%
from math import pi

print(pi)
# Out:
# 3.141592653589793

# %%
from math import pi, sqrt, pow, floor, ceil, log10

print(sqrt(2))
print(math.log10(100))
# Out:
# 1.4142135623730951
# 2.0

# %%
from math import pi as pie

print(pie)
# Out:
# 3.141592653589793

# %% [markdown]
# # string

# %%
import string

# %%
print(string.ascii_letters)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
print(string.digits)
# Out:
# 0123456789

# %%
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %% [markdown]
# # Random

# %%
from random import random, randint

print(random())  # 0 to 1
# Out:
# 0.6519371643743201

# %%
print(random())
# Out:
# 0.009115059552989746

# %%
print(randint(5,20))
# Out:
# 10
